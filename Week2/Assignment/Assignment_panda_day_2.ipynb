# %% [markdown]
# <a href="https://colab.research.google.com/github/nespina/AIandDataScienceWorkshopwithPython/blob/main/Week2/Assignment/Assignment_panda_day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #AI and Data Science Workshop with Python
#
# Assignment 02
#
# Pandas

# %% [markdown]
# Dataset: crash_catalonia.csv.
#
# Dataset Explanation: number of car crashes in Catalonia from 2000 to 2011, by day of week. There are 7 records, with two values each. There is also an initial header line.

# %% [markdown]
# 1- Write a Pandas code to read the dataset. like as the follow:

# %%
import pandas as pd
path ="/content/iris.csv"
df = pd.read_csv("/content/iris.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     618         """
# --> 619         parts = [self.recv(flags, copy=copy, track=track)]
#     620         # have first part already, only loop while more to receive
#
# ...

# %% [markdown]
# 2- Write a code to show the data. The result should be as follow:
#
#
#
# ```
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
#
# ```

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# 3- Write a code to show a statistical summary of the dataset.
# The result should be as follow:
#
# ```
#
# sepal.length	sepal.width	petal.length	petal.width
# count	150.000000	150.000000	150.000000	150.000000
# mean	5.843333	3.057333	3.758000	1.199333
# std	0.828066	0.435866	1.765298	0.762238
# min	4.300000	2.000000	1.000000	0.100000
# 25%	5.100000	2.800000	1.600000	0.300000
# 50%	5.800000	3.000000	4.350000	1.300000
# 75%	6.400000	3.300000	5.100000	1.800000
# max	7.900000	4.400000	6.900000	2.500000
# ```

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# 4- Write a code to print the first three rows of the dataset.
# The output should be as follow:
#
# ```
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# ```

# %%
df[0:3]
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa

# %% [markdown]
# 5- Write a code to print number of rows and columns of the dataset.
# The result can be like this:
#
# ```
# Number of Rows: 150
# Number of Columns: 5
# ```

# %%
total_rows=len(df.axes[0])
total_cols=len(df.axes[1])
print ("Number of Rows:" + str(total_rows))
print ("Number of Columns:" + str(total_cols))
# Out:
# Number of Rows:150
# Number of Columns:5

# %% [markdown]
# 6- Write a code to sort the dataset based on `petal.width` value.
#
# The result should be like this:
# ```
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 32            5.2          4.1           1.5          0.1     Setosa
# 13            4.3          3.0           1.1          0.1     Setosa
# 37            4.9          3.6           1.4          0.1     Setosa
# 9             4.9          3.1           1.5          0.1     Setosa
# 12            4.8          3.0           1.4          0.1     Setosa
# ..            ...          ...           ...          ...        ...
# 140           6.7          3.1           5.6          2.4  Virginica
# 114           5.8          2.8           5.1          2.4  Virginica
# 100           6.3          3.3           6.0          2.5  Virginica
# 144           6.7          3.3           5.7          2.5  Virginica
# 109           7.2          3.6           6.1          2.5  Virginica
# ```

# %%
df.sort_values(by='petal.width')
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 32            5.2          4.1           1.5          0.1     Setosa
# 13            4.3          3.0           1.1          0.1     Setosa
# 37            4.9          3.6           1.4          0.1     Setosa
# 9             4.9          3.1           1.5          0.1     Setosa
# 12            4.8          3.0           1.4          0.1     Setosa
# ..            ...          ...           ...          ...        ...
# 140           6.7          3.1           5.6          2.4  Virginica
# 114           5.8          2.8           5.1          2.4  Virginica
# 100           6.3          3.3           6.0          2.5  Virginica
# 144           6.7          3.3           5.7          2.5  Virginica
# 109           7.2          3.6           6.1          2.5  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 7- Write a code to filter the data by this condition: `variety = Versicolor`

# %%
df[df['variety']=="Versicolor"]
# Out:
#     sepal.length  sepal.width  petal.length  petal.width     variety
# 50           7.0          3.2           4.7          1.4  Versicolor
# 51           6.4          3.2           4.5          1.5  Versicolor
# 52           6.9          3.1           4.9          1.5  Versicolor
# 53           5.5          2.3           4.0          1.3  Versicolor
# 54           6.5          2.8           4.6          1.5  Versicolor
# 55           5.7          2.8           4.5          1.3  Versicolor
# 56           6.3          3.3           4.7          1.6  Versicolor
# 57           4.9          2.4           3.3          1.0  Versicolor
# 58           6.6          2.9           4.6          1.3  Versicolor
# 59           5.2          2.7           3.9          1.4  Versicolor
# 60           5.0          2.0           3.5          1.0  Versicolor
# 61           5.9          3.0           4.2          1.5  Versicolor
# 62           6.0          2.2           4.0          1.0  Versicolor
# ...

# %% [markdown]
# 8- Write a code to change the `variety = Setosa` to `variety = NewValue`.
# The result can be as follow. You can use `replace()` function.
#
# ```
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2   NewValue
# 1             4.9          3.0           1.4          0.2   NewValue
# 2             4.7          3.2           1.3          0.2   NewValue
# 3             4.6          3.1           1.5          0.2   NewValue
# 4             5.0          3.6           1.4          0.2   NewValue
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
# ```

# %%
#dataframe on variety column
df['variety'] = df['variety'].replace('Setosa','NewValue')
print(df)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2   NewValue
# 1             4.9          3.0           1.4          0.2   NewValue
# 2             4.7          3.2           1.3          0.2   NewValue
# 3             4.6          3.1           1.5          0.2   NewValue
# 4             5.0          3.6           1.4          0.2   NewValue
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]
